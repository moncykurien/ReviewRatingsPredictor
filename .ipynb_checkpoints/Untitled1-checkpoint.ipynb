# %%
import nltk
#nltk.download('all')
import pandas as pd
import numpy as np

# %%
pip install snowballstemmer
# Out:
# Requirement already satisfied: snowballstemmer in x:\anacondaenvironment\anaconda3\lib\site-packages (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk import word_tokenize
from nltk.tokenize import RegexpTokenizer

# %%
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('word_tokenize')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\moncy\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\moncy\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading word_tokenize: Package 'word_tokenize' not
# [nltk_data]     found in index
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\moncy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#train_data = pd.read_csv('./combined_data/combined_downsampled_balanced_train_data.csv')
#val_data = pd.read_csv('./combined_data/combined_downsampled_balanced_val_data.csv')
train_data = pd.read_csv('./combined_data/combined_balanced_data.csv')

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416220 entries, 0 to 416219
# Data columns (total 2 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   Reviews  416200 non-null  object
#  1   Ratings  416220 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 6.4+ MB

# %%
train_data.describe()
# Out:
#              Ratings
# count  416220.000000
# mean        3.000000
# std         1.414215
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS, ImageColorGenerator

# %%
train_data['reviews'] = train_data['Reviews'].astype('str')

# %%
rating_1 = train_data[train_data['Ratings']==1]['reviews']
rating_1 = [SnowballStemmer(language='english').stem(word) for word in rating_1]
rating_1 = " ".join(word for word in rating_1)

rating_1_cloud = WordCloud(stopwords = stopwords.words('english'),width=700,height=500,background_color='white', max_words=30).generate(rating_1)

plt.figure(figsize=(10,8), facecolor='r')
plt.imshow(rating_1_cloud)
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
def clean_text(text):
    
    #convert all text to lowercase
    text = text.lower()
    
    #removing the special characters
    tokenizer = RegexpTokenizer(r'\w+')
    
    #tokenizing
    text = tokenizer.tokenize(text)
    
    #Lemmantizing the text
    text = [SnowballStemmer(language='english').stem(word) for word in text]
    
    #remove stopwords
    clean_text = [token for token in text if not token in stopwords.words('english')]
    clean_text = ' '.join(clean_text)
    
    return clean_text

# %%
train_data['reviews'] = train_data['Reviews'].astype('str')
train_data['cleaned_reviews'] = train_data['reviews'].apply(clean_text)
train_data
# Out:
#                                                   Reviews  Ratings  \
# 0        Super sounds.Super Bass quality and sound adhurs        5
# 1                 Nice and good product.Very nice product        5
# 2       This headphone is awesome. Bass is very excell...        5
# 3                   Service is awesome.Service is awesome        5
# 4                 quality.superb sound...😍😍lovely product        5
# ...                                                   ...      ...
# 416215  They were alright to begin with, decent sound ...        2
# 416216  Resmi Note 9 : 4gb ram is warking like 3gb ram...        2
# 416217  Good, but sometimes it disconnects and reconne...        2
# 416218           Nice products but colling ficher missing        2
# 416219  boAt BassHeads 100 in-Ear Wired Earphones with...        2
#
#                                                   reviews  \
# 0        Super sounds.Super Bass quality and sound adhurs
# 1                 Nice and good product.Very nice product
# 2       This headphone is awesome. Bass is very excell...
# 3                   Service is awesome.Service is awesome
# 4                 quality.superb sound...😍😍lovely product
# ...                                                   ...
# 416215  They were alright to begin with, decent sound ...
# 416216  Resmi Note 9 : 4gb ram is warking like 3gb ram...
# 416217  Good, but sometimes it disconnects and reconne...
# 416218           Nice products but colling ficher missing
# 416219  boAt BassHeads 100 in-Ear Wired Earphones with...
#
#                                           cleaned_reviews
# 0              super sound super bass qualiti sound adhur
# 1                     nice good product veri nice product
# 2       headphon awesom bass veri excel veri veri good...
# 3                             servic awesom servic awesom
# 4                       qualiti superb sound love product
# ...                                                   ...
# 416215  alright begin decent sound qualiti fit ear 3 m...
# 416216  resmi note 9 4gb ram wark like 3gb ram batteri...
# 416217  good sometim disconnect reconnect veri irrit b...
# 416218                      nice product coll ficher miss
# 416219  boat basshead 100 ear wire earphon super extra...
#
# [416220 rows x 4 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import make_pipeline

# %%
#Vectorizing
vectorizer = CountVectorizer()
tfidf = TfidfTransformer()

pipe = make_pipeline(vectorizer, tfidf)

# %%
reviews_array = pipe.fit_transform(train_data['cleaned_reviews']).todense()
reviews_array
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-21-116dfb145b9d> in <module>
# ----> 1 reviews_array = pipe.fit_transform(train_data['cleaned_reviews']).todense()
#       2 reviews_array
#
# X:\AnacondaEnvironment\anaconda3\lib\site-packages\scipy\sparse\base.py in todense(self, order, out)
#     849             `numpy.matrix` object that shares the same memory.
#     850         """
# --> 851         return asmatrix(self.toarray(order=order, out=out))
#     852
#     853     def toarray(self, order=None, out=None):
#
# X:\AnacondaEnvironment\anaconda3\lib\site-packages\scipy\sparse\compressed.py in toarray(self, order, out)
#    1023         if out is None and order is None:
#    1024             order = self._swap('cf')[0]
# -> 1025         out = self._process_toarray_args(order, out)
#    1026         if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1027             raise ValueError('Output array must be C or F contiguous')
#
# X:\AnacondaEnvironment\anaconda3\lib\site-packages\scipy\sparse\base.py in _process_toarray_args(self, order, out)
#    1187             return out
#    1188         else:
# -> 1189             return np.zeros(self.shape, dtype=self.dtype, order=order)
#    1190
#    1191
#
# MemoryError: Unable to allocate 119. GiB for an array with shape (416220, 38433) and data type float64

# %%
print(f"The reviews have {reviews_array.shape[1]} columns.")

# %%
from scipy.sparse import csr_matrix

# %%
X = csr_matrix(reviews_array)
print(X)

# %%
y = train_data['Ratings']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, random_state = 42)

naive = MultinomialNB()

naive.fit(x_train, y_train)

y_pred_naive = naive.predict(x_test)

print('Final score: ', accuracy_score(y_test, y_pred_naive))
